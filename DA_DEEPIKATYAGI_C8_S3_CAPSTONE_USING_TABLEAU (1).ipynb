# %% [markdown]
# # CAPSTONE PROJECT BASED ON TABLEAU- CUSTOMER CHURN ANALYSIS

# %% [markdown]
# # BUSINEES OBJECTIVE-

# %%
import numpy as np
import pandas as pd
import matplotlib as mat
import seaborn as sns 
import matplotlib.pyplot as plt
from tabulate import tabulate

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Deepika Tyagi\\Downloads'

# %% [markdown]
# # DATA PRE PROCESSING- USING PYTHON

# %%
data=pd.read_csv("DS1_C8_V3_ND_Sprint3_BankChurn_Data (1).csv")
data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
data.size
# Out:
# 202540

# %%
print (data.shape)
# Out:
# (10127, 20)

# %%
print(data.columns)
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Region', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Trans_Amt', 'Total_Trans_Ct',
#        'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# CLIENTNUM                     0
# Attrition_Flag                0
# Customer_Age                  0
# Gender                        0
# Dependent_count               0
# Education_Level               0
# Marital_Status                0
# Income_Category               0
# Card_Category               132
# Region                        0
# Months_on_book                0
# Total_Relationship_Count      0
# Months_Inactive_12_mon        0
# Contacts_Count_12_mon         0
# Credit_Limit                 60
# Total_Revolving_Bal           0
# Avg_Open_To_Buy               0
# Total_Trans_Amt               0
# Total_Trans_Ct                0
# Avg_Utilization_Ratio         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             9995 non-null   object
#  9   Region                    10127 non-null  object
#  10  Months_on_book            10127 non-null  int64
#  11  Total_Relationship_Count  10127 non-null  int64
#  12  Months_Inactive_12_mon    10127 non-null  int64
# ...

# %%
data.nunique()
# Out:
# CLIENTNUM                   10127
# Attrition_Flag                  2
# Customer_Age                   68
# Gender                          2
# Dependent_count                56
# Education_Level                 7
# Marital_Status                  4
# Income_Category                 6
# Card_Category                   4
# Region                          4
# Months_on_book                 44
# Total_Relationship_Count        6
# Months_Inactive_12_mon          7
# Contacts_Count_12_mon           7
# Credit_Limit                 6181
# Total_Revolving_Bal          1974
# Avg_Open_To_Buy              6813
# Total_Trans_Amt              5033
# Total_Trans_Ct                126
# Avg_Utilization_Ratio         964
# dtype: int64

# %%
data.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#              Region  Months_on_book  Total_Relationship_Count  \
# 0           England              39                         5
# ...

# %%
data.tail(5)
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category    Region  \
# 10122        Graduate         Single     $40K - $60K          Blue   England
# 10123         Unknown       Divorced     $40K - $60K          Blue   England
# 10124     High School        Married  Less than $40K          Blue   England
# 10125        Graduate        Unknown     $40K - $60K          Blue   England
# 10126        Graduate        Married  Less than $40K        Silver  Scotland
#
# ...

# %% [markdown]
# # Null value treatment

# %%
Card_Category_mode = data.Card_Category.mode()[0]
print(f"Mode of Card_Category is {Card_Category_mode}")
data["Card_Category"].fillna(Card_Category_mode, inplace = True)


Credit_Limit_mean = data.Credit_Limit .mean()
print(f"Mean of Credit_Limit is {Credit_Limit_mean}")
data["Credit_Limit"].fillna(Credit_Limit_mean, inplace = True)
# Out:
# Mode of Card_Category is Blue
# Mean of Credit_Limit is 8703.180550312904

# %% [markdown]
# INTERPRETATION:  During Data Pre-processing using Python, firstly we    have loaded the dataset in Jupyter notebook via various libraries of Python. There are 10127 rows and 20 columns in our dataset. Later on we have checked the Null value in the dataset, and we have found 2 columns with null value ,so in order to fill the null value ,we are replacing the null values with measure of central tendency as per requirement.

# %%
data.isnull().sum()
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Region                      0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
def data_types(data):
    cat = []
    num = []
    for i in data.columns:                 
        if data[i].dtypes !='O':      
                                                    
            num.append(i)
        else:
            cat.append(i)
            
    return cat,num 


cat, num = data_types(data)

# %%
print(tabulate({"Categorical":cat,
                "numerical": num}, headers = ["categorical", "numerical"]))
# Out:
# categorical      numerical
# ---------------  ------------------------
# Attrition_Flag   CLIENTNUM
# Gender           Customer_Age
# Education_Level  Dependent_count
# Marital_Status   Months_on_book
# Income_Category  Total_Relationship_Count
# Card_Category    Months_Inactive_12_mon
# Region           Contacts_Count_12_mon
#                  Credit_Limit
#                  Total_Revolving_Bal
#                  Avg_Open_To_Buy
#                  Total_Trans_Amt
#                  Total_Trans_Ct
#                  Avg_Utilization_Ratio

# %% [markdown]
# # Display the summary Statistics of the dataset

# %%
data.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.382245         2.787400       35.928409
# std    3.690378e+07      8.341393         6.479135        7.986416
# min    7.080821e+08     18.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     89.000000       143.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %% [markdown]
# INTERPRETATION:   Here we have present the summary statistics of the dataset, including the separation of Categorical and Numerical columns. As we have also present here the information about dataset like as datatype etc. So by doing all the above discussed steps of Data Preprocessing, we are cleaning our dataset.

# %% [markdown]
# # OUTLIERS ANALYSIS

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=data["Dependent_count"])
plt.title('Box and Whisker Plot of Dependent_count')
plt.xlabel('Dependent_count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=data["Credit_Limit"])
plt.title('Box and Whisker Plot of Credit_Limit')
plt.xlabel('Credit_Limit')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=data["Total_Trans_Amt"])
plt.title('Box and Whisker Plot of Total_Trans_Amt')
plt.xlabel('Total_Trans_Amt')
plt.show()

# %% [markdown]
# INTERPRETATION: The most important step of Data Cleaning is to identify the outliers. So by using the Box Plot method ,we have found that there are so many outliers in 3 Numerical columns such as  ‘Credit_limit’,’Dependent_count’ and ‘Total_trans_Amt’.
#                            We can remove the outliers either by replacing them with ‘Mean’ or by ‘IQR’ method. This was the final step of Cleaning,so for now our Data is completely clean .So we are uploading this in ‘CSV’ file for further and deeper analysis through visualization

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=data["Total_Trans_Ct"])
plt.title('Box and Whisker Plot of Total_Trans_Ct')
plt.xlabel('Total_Trans_Ct')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=data["Avg_Utilization_Ratio"])
plt.title('Box and Whisker Plot of Avg_Utilization_Ratio')
plt.xlabel('Avg_Utilization_Ratio')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=data["Total_Revolving_Bal"])
plt.title('Box and Whisker Plot ofTotal_Revolving_Bal')
plt.xlabel('Total_Revolving_Bal')
plt.show()

# %%
data.to_csv("Bank churn data Tableau Capstone.csv")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Deepika Tyagi\\Downloads'
